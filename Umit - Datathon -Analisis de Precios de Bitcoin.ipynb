# %%
# Importar librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import missingno as msno
import statsmodels.api as sm


# Configurar estilo de visualizaciones
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (6, 4)
# %matplotlib inline

# Load dataset
data_path = "/Users/umitgungor/Desktop/Factoria F5 IA-2025/Tareas/EDA/Umit PROYECTO IV Datathon/btcusd_1-min_data.csv"
df = pd.read_csv("/Users/umitgungor/Desktop/Factoria F5 IA-2025/Tareas/EDA/Umit PROYECTO IV Datathon/btcusd_1-min_data.csv")

# %%
# Check basic info & missing values
print("Dataset Information:\n", df.info(), "\n")
print("Missing Values:\n", df.isnull().sum(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7188157 entries, 0 to 7188156
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  float64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
# dtypes: float64(6)
# memory usage: 329.0 MB
# Dataset Information:
#  None
#
# Missing Values:
#  Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64

# %%
print('Cantidad de Filas y columnas:',df.shape)
print('Nombre columnas:',df.columns)
# Out:
# Cantidad de Filas y columnas: (7188157, 6)
# Nombre columnas: Index(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
# Cantidad de valores faltantes por columna
print(df.isnull().sum())
# Out:
# Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64

# %%
#Verifiquemos si hay correlación entre los datos
corr = df[['Open', 'High', 'Low', 'Close', 'Volume',]].corr()
sm.graphics.plot_corr(corr, xnames=list(corr.columns))
plt.show()

# %%
anomalies = []
 
# Funcion ejemplo para detección de outliers
def find_anomalies(data):
    # Set upper and lower limit to 2 standard deviation
    data_std = data.std()
    data_mean = data.mean()
    anomaly_cut_off = data_std * 2
    lower_limit  = data_mean - anomaly_cut_off 
    upper_limit = data_mean + anomaly_cut_off
    print(lower_limit.iloc[0])
    print(upper_limit.iloc[0])
 
    # Generate outliers
    for index, row in data.iterrows():
        outlier = row # # obtener primer columna
        # print(outlier)
        if (outlier.iloc[0] > upper_limit.iloc[0]) or (outlier.iloc[0] < lower_limit.iloc[0]):
            anomalies.append(index)
    return anomalies
 
find_anomalies(df.set_index('High')[['Low']])
# Out:
# -35856.876978502914
# 75213.07472240026
# [75374.0,
#  75311.0,
#  75267.0,
#  75294.0,
#  75330.0,
#  75318.0,
#  75356.0,
#  75369.0,
#  75391.0,
#  75409.0,
#  75387.0,
#  75402.0,
#  75390.0,
#  75466.0,
#  75485.0,
#  75484.0,
#  75494.0,
#  75478.0,
#  75357.0,
#  75466.0,
#  75489.0,
#  75476.0,
#  75466.0,
#  75449.0,
#  75472.0,
#  75499.0,
#  75490.0,
#  75441.0,
#  75489.0,
#  75500.0,
#  75531.0,
#  75520.0,
#  75534.0,
#  75541.0,
#  75595.0,
#  75547.0,
#  75417.0,
#  75484.0,
#  75411.0,
#  75306.0,
#  75356.0,
#  75368.0,
#  75382.0,
#  75364.0,
#  75392.0,
#  75505.0,
#  75533.0,
#  75604.0,
#  75623.0,
#  75605.0,
#  75631.0,
#  75723.0,
#  75734.0,
#  75759.0,
#  75770.0,
#  75792.0,
#  75800.0,
#  75851.0,
#  75889.0,
#  75911.0,
#  75914.0,
#  75959.0,
#  75914.0,
#  75948.0,
#  75931.0,
#  75946.0,
#  75854.0,
#  75766.0,
#  75814.0,
#  75804.0,
#  75819.0,
#  75948.0,
#  75976.0,
#  76050.0,
#  76120.0,
#  76114.0,
#  76070.0,
#  76120.0,
#  76125.0,
# ...
